# %%
import pandas as pd
import gmplot
import mplleaflet
import matplotlib.pyplot as plt
import folium

# %%
data = pd.read_csv("cl_apts.csv")
data
# Out:
#      heart        lat        long
# 0    False  37.763472 -122.423787
# 1    False  37.757421 -122.408885
# 2    False  37.769629 -122.423723
# 3    False  37.769636 -122.420912
# 4    False  37.766136 -122.421012
# ..     ...        ...         ...
# 437  False  37.747830 -122.424768
# 438  False  37.757167 -122.416720
# 439  False  37.752538 -122.413517
# 440  False  37.768056 -122.419680
# 441  False  37.767882 -122.419944
#
# [442 rows x 3 columns]

# %%
coords = data[data["heart"] == True][["lat", "long"]]
std_coords = data[data["heart"] == False][["lat", "long"]]

# %%
lat_mean, long_mean = coords.mean(axis=0)
std_lat_mean, std_long_mean = std_coords.mean(axis=0)

# %%
map = folium.Map(location=[37.7569,-122.4145], zoom_start=13)
for coord in coords.iterrows():
    folium.CircleMarker(location=[coord[1].lat, coord[1].long],
                  color='red', 
                  radius=4,
                 ).add_to(map)
    
folium.Marker(location=[lat_mean, long_mean],
                  icon=folium.Icon(
                                  color='pink',
                                  icon='heart',    # icon code from above link
                                  prefix='glyphicon')
                 ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map = folium.Map(location=[37.7569,-122.4145], zoom_start=13)

folium.Marker(location=[lat_mean, long_mean],
                  icon=folium.Icon(
                                  color='pink',
                                  icon='heart',    # icon code from above link
                                  prefix='glyphicon')).add_to(map)
    
for coord in std_coords.iterrows():
    folium.CircleMarker(location=[coord[1].lat, coord[1].long],
                  color='gray', 
                  radius=4,
                 ).add_to(map)
    
for coord in coords.iterrows():
    folium.CircleMarker(location=[coord[1].lat, coord[1].long],
                  color='red', 
                  radius=4,
                 ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
